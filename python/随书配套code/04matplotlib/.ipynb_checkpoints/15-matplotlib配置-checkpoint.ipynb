# %%
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
plt.plot(range(0,10))
plt.plot(range(0,10,2))

# %%
from matplotlib import cycler
plt.rcParams['axes.prop_cycle'] = cycler('color', ['k', 'y'])
plt.rcParams['font.sans-serif'] = ['STHupo']
plt.rcParams['font.size'] = 20
plt.plot(range(0,10))
plt.plot(range(0,10,2))
plt.title("测试")
# Out:
# Text(0.5, 1.0, '测试')

# %%
# 获取 Matplotlib 库的配置路径
mpl.get_configdir()
# Out:
# 'C:\\Users\\Awen\\.matplotlib'

# %%
# 使用 plt.style.use() 函数设置 Matplotlib 库绘图的样式
plt.style.use("iflytek")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\python3.6.6\lib\site-packages\matplotlib\style\core.py in use(style)
#     110             try:
# --> 111                 rc = rc_params_from_file(style, use_default_template=False)
#     112                 _apply_style(rc)
#
# d:\python3.6.6\lib\site-packages\matplotlib\__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#    1069     """
# -> 1070     config_from_file = _rc_params_in_file(fname, fail_on_error)
#    1071
#
# d:\python3.6.6\lib\site-packages\matplotlib\__init__.py in _rc_params_in_file(fname, fail_on_error)
#     985     rc_temp = {}
# --> 986     with _open_file_or_url(fname) as fd:
#     987         try:
#
# d:\python3.6.6\lib\contextlib.py in __enter__(self)
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#
# ...

# %%
plt.plot(range(0,10))
plt.title("你好")
# Out:
# Text(0.5, 1.0, '你好')

# %% [markdown]
# # 笔记:
# 1. 动态设置配置:通过plt.rcParams来设置.
# 2. 配置文件配置:把配置项放到[名称].pltstyle文件中,然后把这个文件放在`matplotlib.get_configdir()/stylelib`下,以后在代码中就通过`plt.style.use("名称")`就可以使用了.
# 3. 配置项:https://raw.githubusercontent.com/matplotlib/matplotlib/master/matplotlibrc.template
