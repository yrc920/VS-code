# %%
from pyecharts.charts import Boxplot
import pandas as pd
from pyecharts import options as opts

# %%
v1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880]
    + [1000, 980, 930, 650, 760, 810, 1000, 1000, 960, 960],
    [960, 940, 960, 940, 880, 800, 850, 880, 900]
    + [840, 830, 790, 810, 880, 880, 830, 800, 790, 760, 800],
]

v2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760]
    + [910, 920, 890, 860, 880, 720, 840, 850, 850, 780],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870]
    + [870, 810, 740, 810, 940, 950, 800, 810, 870],
]

c = Boxplot()
c.add_xaxis(['商品1','商品2'])
c.add_yaxis("A",c.prepare_data(v1))
c.add_yaxis("B",c.prepare_data(v2))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="4f6deb65be234a94a94f9e2916fbdd69" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_4f6deb65be234a94a94f9e2916fbdd69 = echarts.init(
#             document.getElementById('4f6deb65be234a94a94f9e2916fbdd69'), 'white', {renderer: 'canvas'});
#         var option_4f6deb65be234a94a94f9e2916fbdd69 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "data": [
#                 [
#                     650,
#                     850.0,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "data": [
#                 [
#                     720,
#                     762.5,
#                     815.0,
#                     875.0,
#                     920
#                 ],
#                 [
#                     740,
#                     802.5,
#                     810.0,
#                     870.0,
#                     950
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5546\u54c11",
#                 "\u5546\u54c12"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_4f6deb65be234a94a94f9e2916fbdd69.setOption(option_4f6deb65be234a94a94f9e2916fbdd69);
#     });
# </script>

# %%
athletes = pd.read_csv("athlete_events.csv")
athletes.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
countries = {
    'CHN':'中国',
    'JPN':"日本",
    'KOR':'韩国',
    'USA':"美国",
    'CAN':"加拿大",
    'BRA':"巴西",
    'GBR':"英国",
    'FRA':"法国",
    'ITA':"意大利",
    'ETH':"埃塞俄比亚",
    'KEN':"肯尼亚",
    'NIG':"尼日利亚",
}
my_athletes = athletes[athletes['NOC'].isin(list(countries.keys()))]
man_athletes = []
woman_athletes = []
for country in countries.keys():
    man_heights = my_athletes[(my_athletes['NOC']==country)&(my_athletes['Sex']=='M')]['Height'].dropna()
    woman_heights = my_athletes[(my_athletes['NOC']==country)&(my_athletes['Sex']=='F')]['Height'].dropna()
    man_athletes.append(man_heights)
    woman_athletes.append(woman_heights)

c = Boxplot(init_opts=opts.InitOpts(
    width="800px",
    height="400px",
    animation_opts=opts.AnimationOpts(animation=False)
))
c.add_xaxis(list(countries.values()))
# c.add_xaxis(list(range(len(countries))))
c.add_yaxis("男性运动员",c.prepare_data(man_athletes))
c.add_yaxis("女性运动员",c.prepare_data(woman_athletes))
c.set_global_opts(
    yaxis_opts=opts.AxisOpts(interval=20,min_=120,max_=240)
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="7ee164bcfa754d2dbde20a33348b1ca1" style="width:800px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_7ee164bcfa754d2dbde20a33348b1ca1 = echarts.init(
#             document.getElementById('7ee164bcfa754d2dbde20a33348b1ca1'), 'white', {renderer: 'canvas'});
#         var option_7ee164bcfa754d2dbde20a33348b1ca1 = {
#     "animation": false,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "\u7537\u6027\u8fd0\u52a8\u5458",
#             "data": [
#                 [
#                     148.0,
#                     170.0,
#                     178.0,
#                     185.0,
#                     226.0
#                 ],
#                 [
#                     147.0,
#                     166.0,
#                     172.0,
#                     178.0,
#                     208.0
#                 ],
#                 [
#                     152.0,
#                     169.0,
#                     175.0,
#                     180.0,
#                     207.0
#                 ],
#                 [
#                     140.0,
#                     175.0,
#                     181.0,
#                     188.0,
#                     223.0
#                 ],
#                 [
#                     132.0,
#                     175.0,
#                     180.0,
#                     185.0,
#                     216.0
#                 ],
#                 [
#                     152.0,
#                     175.0,
#                     181.0,
#                     187.0,
#                     217.0
#                 ],
#                 [
#                     143.0,
#                     174.0,
#                     180.0,
#                     185.0,
#                     211.0
#                 ],
#                 [
#                     150.0,
#                     172.0,
#                     178.0,
#                     185.0,
#                     218.0
#                 ],
#                 [
#                     145.0,
#                     172.0,
#                     178.0,
#                     184.0,
#                     215.0
#                 ],
#                 [
#                     157.0,
#                     168.0,
#                     173.0,
#                     177.0,
#                     192.0
#                 ],
#                 [
#                     152.0,
#                     170.0,
#                     174.0,
#                     180.0,
#                     201.0
#                 ],
#                 [
#                     163.0,
#                     167.5,
#                     172.0,
#                     178.0,
#                     207.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "\u5973\u6027\u8fd0\u52a8\u5458",
#             "data": [
#                 [
#                     136.0,
#                     163.0,
#                     169.0,
#                     175.0,
#                     206.0
#                 ],
#                 [
#                     140.0,
#                     157.0,
#                     161.0,
#                     166.0,
#                     191.0
#                 ],
#                 [
#                     139.0,
#                     162.0,
#                     166.0,
#                     171.0,
#                     202.0
#                 ],
#                 [
#                     139.0,
#                     162.0,
#                     168.0,
#                     175.0,
#                     203.0
#                 ],
#                 [
#                     136.0,
#                     163.0,
#                     168.0,
#                     173.0,
#                     198.0
#                 ],
#                 [
#                     133.0,
#                     162.0,
#                     169.0,
#                     176.0,
#                     200.0
#                 ],
#                 [
#                     137.0,
#                     163.0,
#                     169.0,
#                     173.0,
#                     195.0
#                 ],
#                 [
#                     140.0,
#                     162.0,
#                     167.0,
#                     172.0,
#                     197.0
#                 ],
#                 [
#                     141.0,
#                     162.0,
#                     167.0,
#                     172.0,
#                     201.0
#                 ],
#                 [
#                     152.0,
#                     160.0,
#                     164.0,
#                     167.0,
#                     180.0
#                 ],
#                 [
#                     150.0,
#                     157.0,
#                     162.0,
#                     168.0,
#                     185.0
#                 ],
#                 [
#                     163.0,
#                     164.0,
#                     168.0,
#                     170.5,
#                     172.0
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7537\u6027\u8fd0\u52a8\u5458",
#                 "\u5973\u6027\u8fd0\u52a8\u5458"
#             ],
#             "selected": {
#                 "\u7537\u6027\u8fd0\u52a8\u5458": true,
#                 "\u5973\u6027\u8fd0\u52a8\u5458": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
