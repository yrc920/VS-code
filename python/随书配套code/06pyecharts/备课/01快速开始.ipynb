# %%
from pyecharts.charts import Bar,Boxplot,Scatter,Geo,Map,Graph,Scatter
from pyecharts.commons.utils import JsCode
from pyecharts import options as opts
from pyecharts.globals import ThemeType
from faker import Faker
import os,json

# %%
c = (
        Bar(
            init_opts=opts.InitOpts(
                width="500px",
                height="400px",
                theme=ThemeType.LIGHT,
                bg_color="skyblue"
            )
        )
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="3d9aef7ac238431aa245184dcf7fde0d" style="width:500px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_3d9aef7ac238431aa245184dcf7fde0d = echarts.init(
#             document.getElementById('3d9aef7ac238431aa245184dcf7fde0d'), 'light', {renderer: 'canvas'});
#         var option_3d9aef7ac238431aa245184dcf7fde0d = {
#     "backgroundColor": "skyblue",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 124,
#                 104,
#                 41,
#                 28,
#                 114,
#                 106,
#                 131
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 91,
#                 150,
#                 64,
#                 62,
#                 52,
#                 24,
#                 112
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_3d9aef7ac238431aa245184dcf7fde0d.setOption(option_3d9aef7ac238431aa245184dcf7fde0d);
#     });
# </script>

# %%
c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(
            title="销售表",
            pos_right="0",
            pos_bottom="2px",
            title_textstyle_opts=opts.TextStyleOpts(**{"color":"#333","font_size":12})
        ))
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="ac0a2bca855e44fd8ed96b2bc3c26a95" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_ac0a2bca855e44fd8ed96b2bc3c26a95 = echarts.init(
#             document.getElementById('ac0a2bca855e44fd8ed96b2bc3c26a95'), 'white', {renderer: 'canvas'});
#         var option_ac0a2bca855e44fd8ed96b2bc3c26a95 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 66,
#                 92,
#                 44,
#                 115,
#                 104,
#                 66,
#                 122
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 47,
#                 97,
#                 86,
#                 145,
#                 125,
#                 84,
#                 90
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u9500\u552e\u8868",
#             "right": "0",
#             "bottom": "2px",
#             "textStyle": {
#                 "color": "#333",
#                 "fontSize": 12
#             }
#         }
#     ]
# };
#         chart_ac0a2bca855e44fd8ed96b2bc3c26a95.setOption(option_ac0a2bca855e44fd8ed96b2bc3c26a95);
#     });
# </script>

# %%
c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            legend_opts=opts.LegendOpts(selected_mode="mutiple",orient="vertical",pos_right="30px")
        )
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="84c9f6da297044ecb4fef0060be8a137" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_84c9f6da297044ecb4fef0060be8a137 = echarts.init(
#             document.getElementById('84c9f6da297044ecb4fef0060be8a137'), 'white', {renderer: 'canvas'});
#         var option_84c9f6da297044ecb4fef0060be8a137 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 90,
#                 86,
#                 149,
#                 104,
#                 75,
#                 55,
#                 111
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 25,
#                 40,
#                 61,
#                 86,
#                 139,
#                 45,
#                 68
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "selectedMode": "mutiple",
#             "show": true,
#             "right": "30px",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ]
# };
#         chart_84c9f6da297044ecb4fef0060be8a137.setOption(option_84c9f6da297044ecb4fef0060be8a137);
#     });
# </script>

# %%
c = (
        Bar()
        .add_xaxis(
            [
                "名字很长的X轴标签1",
                "名字很长的X轴标签2",
                "名字很长的X轴标签3",
                "名字很长的X轴标签4",
                "名字很长的X轴标签5",
                "名字很长的X轴标签6",
            ]
        )
        .add_yaxis("商家A", [10, 20, 30, 40, 50, 40])
        .add_yaxis("商家B", [20, 10, 40, 30, 40, 50])
        .set_global_opts(
            xaxis_opts=opts.AxisOpts(
                name="商家名称",
                axislabel_opts=opts.LabelOpts(rotate=-15),
                axisline_opts = opts.AxisLineOpts(symbol="arrow",linestyle_opts=opts.LineStyleOpts(width=2)),
                axistick_opts = opts.AxisTickOpts(is_inside=True,length=20),
                axispointer_opts = opts.AxisPointerOpts(is_show=True,type_="line")
            )
        )
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="19e98e0e654c450080815b1b3755af99" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_19e98e0e654c450080815b1b3755af99 = echarts.init(
#             document.getElementById('19e98e0e654c450080815b1b3755af99'), 'white', {renderer: 'canvas'});
#         var option_19e98e0e654c450080815b1b3755af99 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 10,
#                 20,
#                 30,
#                 40,
#                 50,
#                 40
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 20,
#                 10,
#                 40,
#                 30,
#                 40,
#                 50
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "name": "\u5546\u5bb6\u540d\u79f0",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "symbol": "arrow",
#                 "lineStyle": {
#                     "width": 2,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": true,
#                 "length": 20
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "axisPointer": {
#                 "show": true,
#                 "type": "line"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e1",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e2",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e3",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e4",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e5",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e6"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ]
# };
#         chart_19e98e0e654c450080815b1b3755af99.setOption(option_19e98e0e654c450080815b1b3755af99);
#     });
# </script>

# %%
c = (
        Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values, color=Faker.rand_color())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-垂直）"),
            datazoom_opts=opts.DataZoomOpts(orient="vertical"),
        )
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="4fbc5c8264804fef9f145c3e54978519" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_4fbc5c8264804fef9f145c3e54978519 = echarts.init(
#             document.getElementById('4fbc5c8264804fef9f145c3e54978519'), 'white', {renderer: 'canvas'});
#         var option_4fbc5c8264804fef9f145c3e54978519 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#61a0a8",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 2,
#                 9,
#                 12,
#                 27,
#                 4,
#                 18,
#                 23,
#                 29,
#                 18,
#                 24,
#                 23,
#                 26,
#                 21,
#                 15,
#                 1,
#                 21,
#                 1,
#                 30,
#                 25,
#                 26,
#                 20,
#                 22,
#                 6,
#                 15,
#                 22,
#                 14,
#                 29,
#                 5,
#                 15,
#                 5
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u5782\u76f4\uff09"
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "vertical",
#         "zoomLock": false
#     }
# };
#         chart_4fbc5c8264804fef9f145c3e54978519.setOption(option_4fbc5c8264804fef9f145c3e54978519);
#     });
# </script>

# %%
v1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880]
    + [1000, 980, 930, 650, 760, 810, 1000, 1000, 960, 960],
    [960, 940, 960, 940, 880, 800, 850, 880, 900]
    + [840, 830, 790, 810, 880, 880, 830, 800, 790, 760, 800],
]
v2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760]
    + [910, 920, 890, 860, 880, 720, 840, 850, 850, 780],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870]
    + [870, 810, 740, 810, 940, 950, 800, 810, 870],
]
c = Boxplot()
c.add_xaxis(["expr1", "expr2"]).add_yaxis("A", c.prepare_data(v1)).add_yaxis(
    "B", c.prepare_data(v2)
).set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="94865678ad694af49485bb6770577629" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_94865678ad694af49485bb6770577629 = echarts.init(
#             document.getElementById('94865678ad694af49485bb6770577629'), 'white', {renderer: 'canvas'});
#         var option_94865678ad694af49485bb6770577629 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "data": [
#                 [
#                     650,
#                     850.0,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "data": [
#                 [
#                     720,
#                     762.5,
#                     815.0,
#                     875.0,
#                     920
#                 ],
#                 [
#                     740,
#                     802.5,
#                     810.0,
#                     870.0,
#                     950
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_94865678ad694af49485bb6770577629.setOption(option_94865678ad694af49485bb6770577629);
#     });
# </script>

# %%
c = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Scatter-基本示例"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="7fe373eacf374f2596691e15acb16fc3" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_7fe373eacf374f2596691e15acb16fc3 = echarts.init(
#             document.getElementById('7fe373eacf374f2596691e15acb16fc3'), 'white', {renderer: 'canvas'});
#         var option_7fe373eacf374f2596691e15acb16fc3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     81
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     124
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     123
#                 ],
#                 [
#                     "\u5468\u56db",
#                     83
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     38
#                 ],
#                 [
#                     "\u5468\u516d",
#                     55
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     86
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_7fe373eacf374f2596691e15acb16fc3.setOption(option_7fe373eacf374f2596691e15acb16fc3);
#     });
# </script>

# %%
c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Scatter-显示分割线"),
            xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
            yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
        )
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="72c4895ee9dd4513898b66b0c34b0fb7" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_72c4895ee9dd4513898b66b0c34b0fb7 = echarts.init(
#             document.getElementById('72c4895ee9dd4513898b66b0c34b0fb7'), 'white', {renderer: 'canvas'});
#         var option_72c4895ee9dd4513898b66b0c34b0fb7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 25,
#                 137,
#                 41,
#                 90,
#                 82,
#                 65,
#                 64
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u663e\u793a\u5206\u5272\u7ebf"
#         }
#     ]
# };
#         chart_72c4895ee9dd4513898b66b0c34b0fb7.setOption(option_72c4895ee9dd4513898b66b0c34b0fb7);
#     });
# </script>

# %%
c = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis(
        "商家A",
        [list(z) for z in zip(Faker.values(), Faker.choose())],
        label_opts=opts.LabelOpts(
            formatter=JsCode(
                "function(params){return params.value[1] +' : '+ params.value[2];}"
            )
        ),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Scatter-多维度数据"),
        tooltip_opts=opts.TooltipOpts(
            formatter=JsCode(
                "function (params) {return params.name + ' : ' + params.value[2];}"
            )
        ),
        visualmap_opts=opts.VisualMapOpts(
            type_="color", max_=150, min_=20, dimension=1
        ),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="045e626ddd7049a9a5c6711634b801bd" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_045e626ddd7049a9a5c6711634b801bd = echarts.init(
#             document.getElementById('045e626ddd7049a9a5c6711634b801bd'), 'white', {renderer: 'canvas'});
#         var option_045e626ddd7049a9a5c6711634b801bd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     70,
#                     "\u5468\u4e00"
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     102,
#                     "\u5468\u4e8c"
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     139,
#                     "\u5468\u4e09"
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     66,
#                     "\u5468\u56db"
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     101,
#                     "\u5468\u4e94"
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     145,
#                     "\u5468\u516d"
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     96,
#                     "\u5468\u65e5"
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": function(params){return params.value[1] +' : '+ params.value[2];}
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {return params.name + ' : ' + params.value[2];},
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u591a\u7ef4\u5ea6\u6570\u636e"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 20,
#         "max": 150,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "dimension": 1,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_045e626ddd7049a9a5c6711634b801bd.setOption(option_045e626ddd7049a9a5c6711634b801bd);
#     });
# </script>

# %%
c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.provinces, Faker.values())], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-VisualMap（连续型）"),
        visualmap_opts=opts.VisualMapOpts(max_=200),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="6e178aaacb014794a447eebcf4e1988b" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_6e178aaacb014794a447eebcf4e1988b = echarts.init(
#             document.getElementById('6e178aaacb014794a447eebcf4e1988b'), 'white', {renderer: 'canvas'});
#         var option_6e178aaacb014794a447eebcf4e1988b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 58
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 92
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 69
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u8fde\u7eed\u578b\uff09"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_6e178aaacb014794a447eebcf4e1988b.setOption(option_6e178aaacb014794a447eebcf4e1988b);
#     });
# </script>

# %%
c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.country, Faker.values())], "world")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-世界地图"),
        visualmap_opts=opts.VisualMapOpts(max_=200),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#     <div id="d4b1d49e516f4bdca6f04dc490a203a2" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'world'], function(echarts) {
#         var chart_d4b1d49e516f4bdca6f04dc490a203a2 = echarts.init(
#             document.getElementById('d4b1d49e516f4bdca6f04dc490a203a2'), 'white', {renderer: 'canvas'});
#         var option_d4b1d49e516f4bdca6f04dc490a203a2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 69
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 26
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 124
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 90
#                 },
#                 {
#                     "name": "United States",
#                     "value": 72
#                 },
#                 {
#                     "name": "Africa",
#                     "value": 144
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 46
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-\u4e16\u754c\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_d4b1d49e516f4bdca6f04dc490a203a2.setOption(option_d4b1d49e516f4bdca6f04dc490a203a2);
#     });
# </script>

# %%
with open(os.path.join("fixtures", "weibo.json"), "r", encoding="utf-8") as f:
    j = json.load(f)
    nodes, links, categories, cont, mid, userl = j
c = (
    Graph()
    .add(
        "",
        nodes,
        links,
        categories,
        repulsion=50,
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        title_opts=opts.TitleOpts(title="Graph-微博转发关系图"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="0a6652f42b714de2b146412f40a85710" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_0a6652f42b714de2b146412f40a85710 = echarts.init(
#             document.getElementById('0a6652f42b714de2b146412f40a85710'), 'white', {renderer: 'canvas'});
#         var option_0a6652f42b714de2b146412f40a85710 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 50,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0.2,
#                 "type": "solid"
#             },
#             "roam": true,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Camel3942",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "category": "Camel3942",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Christinez",
#                     "symbolSize": 13,
#                     "draggable": "False",
#                     "value": 7,
#                     "category": "Christinez",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "JoannaBlue",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "category": "JoannaBlue",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Michael-Cheung-",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "category": "Michael-Cheung-",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "NKmilitaryStudies",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "category": "NKmilitaryStudies",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Syfannn",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "category": "Syfannn",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Tiger\u516c\u5b50",
#                     "symbolSize": 13,
#                     "draggable": "False",
#                     "value": 7,
#                     "category": "Tiger\u516c\u5b50",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "VeryE",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "category": "VeryE",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "X_iao\u6a13",
#                     "symbolSize": 12,
#                     "draggable": "False",
#                     "value": 6,
#                     "category": "X_iao\u6a13",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Xiao-\u658c\u6770",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "category": "Xiao-\u658c\u6770",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "_nearly\u8f6c1",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "category": "_nearly\u8f6c1",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "lfx160219",
#                     "symbolSize": 14,
#                     "draggable": "False",
#                     "value": 8,
#                     "category": "lfx160219",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "offfarmworkes2",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "category": "offfarmworkes2",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "sazen",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "category": "sazen",
#                     "label": {
#                         "normal": {
#                             "show": "True"
#                         }
#                     }
#                 },
#                 {
#                     "name": "stephen1999c",
#                     "symbolSize": 5,
#                     "draggable": "False",
#                     "value": 1,
#                     "ca

# %%
c = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A",Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Scatter-多维度数据"),
        tooltip_opts=opts.TooltipOpts(
            formatter=JsCode(
                "function (params) {return params.value}"
            )
        )
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="5ae4f51ecc8142eab9e52f7e42e18b6a" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_5ae4f51ecc8142eab9e52f7e42e18b6a = echarts.init(
#             document.getElementById('5ae4f51ecc8142eab9e52f7e42e18b6a'), 'white', {renderer: 'canvas'});
#         var option_5ae4f51ecc8142eab9e52f7e42e18b6a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u54c8\u58eb\u5947",
#                     117
#                 ],
#                 [
#                     "\u8428\u6469\u8036",
#                     68
#                 ],
#                 [
#                     "\u6cf0\u8fea",
#                     71
#                 ],
#                 [
#                     "\u91d1\u6bdb",
#                     106
#                 ],
#                 [
#                     "\u7267\u7f8a\u72ac",
#                     44
#                 ],
#                 [
#                     "\u5409\u5a03\u5a03",
#                     137
#                 ],
#                 [
#                     "\u67ef\u57fa",
#                     27
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {return params.value},
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u591a\u7ef4\u5ea6\u6570\u636e"
#         }
#     ]
# };
#         chart_5ae4f51ecc8142eab9e52f7e42e18b6a.setOption(option_5ae4f51ecc8142eab9e52f7e42e18b6a);
#     });
# </script>

# %%
c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(type_='size',max_=200),
        )
    )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="04cd88f3b39548d8ae88f0cbb60ac407" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_04cd88f3b39548d8ae88f0cbb60ac407 = echarts.init(
#             document.getElementById('04cd88f3b39548d8ae88f0cbb60ac407'), 'white', {renderer: 'canvas'});
#         var option_04cd88f3b39548d8ae88f0cbb60ac407 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 73,
#                 63,
#                 41,
#                 24,
#                 122,
#                 45,
#                 87
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "symbolSize": [
#                 20,
#                 50
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_04cd88f3b39548d8ae88f0cbb60ac407.setOption(option_04cd88f3b39548d8ae88f0cbb60ac407);
#     });
# </script>
