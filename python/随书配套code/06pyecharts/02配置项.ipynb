# %%
from pyecharts.charts import Bar,Scatter
from pyecharts import options as opts
from faker import Faker
from pyecharts.commons.utils import JsCode

# %%
c = (
    Bar(init_opts=opts.InitOpts(
        width="400px",
        height="300px",
        bg_color="#ccc",
        animation_opts=opts.AnimationOpts(animation=False)
    ))
    .add_xaxis(Faker.choose())
    .add_yaxis("商品",Faker.values())
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="00c5bf3378a949d0bcf2fdaf266fdf11" style="width:400px; height:300px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_00c5bf3378a949d0bcf2fdaf266fdf11 = echarts.init(
#             document.getElementById('00c5bf3378a949d0bcf2fdaf266fdf11'), 'white', {renderer: 'canvas'});
#         var option_00c5bf3378a949d0bcf2fdaf266fdf11 = {
#     "backgroundColor": "#ccc",
#     "animation": false,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u54c1",
#             "data": [
#                 88,
#                 70,
#                 135,
#                 92,
#                 100,
#                 142,
#                 63
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u54c1"
#             ],
#             "selected": {
#                 "\u5546\u54c1": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_00c5bf3378a949d0bcf2fdaf266fdf11.setOption(option_00c5bf3378a949d0bcf2fdaf266fdf11);
#     });
# </script>

# %%
c = (
    Bar(
        init_opts=opts.InitOpts(width="400px",height="300px")
    )
    .add_xaxis(Faker.choose())
    .add_yaxis("商品",Faker.values())
    .set_global_opts(
        title_opts = opts.TitleOpts(
            title="商品售出情况",
            subtitle="子标题",
            pos_right="20px",
            title_textstyle_opts=opts.TextStyleOpts(font_size=12)
        )
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="eafcaf68c0ad4568b5f95fbf913866c9" style="width:400px; height:300px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_eafcaf68c0ad4568b5f95fbf913866c9 = echarts.init(
#             document.getElementById('eafcaf68c0ad4568b5f95fbf913866c9'), 'white', {renderer: 'canvas'});
#         var option_eafcaf68c0ad4568b5f95fbf913866c9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u54c1",
#             "data": [
#                 144,
#                 43,
#                 106,
#                 31,
#                 135,
#                 40,
#                 45
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u54c1"
#             ],
#             "selected": {
#                 "\u5546\u54c1": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5546\u54c1\u552e\u51fa\u60c5\u51b5",
#             "subtext": "\u5b50\u6807\u9898",
#             "right": "20px",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ]
# };
#         chart_eafcaf68c0ad4568b5f95fbf913866c9.setOption(option_eafcaf68c0ad4568b5f95fbf913866c9);
#     });
# </script>

# %%
c = (
    Bar(
        init_opts=opts.InitOpts(width="500px",height="300px")
    )
    .add_xaxis(Faker.clothes)
    .add_yaxis("第一季度",Faker.values(),gap="0%")
    .add_yaxis("第二季度",Faker.values(),gap="0%")
    .set_global_opts(
        legend_opts=opts.LegendOpts(selected_mode="single",orient="vertical")
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="cb85edc54f124960ba93855b5f072836" style="width:500px; height:300px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_cb85edc54f124960ba93855b5f072836 = echarts.init(
#             document.getElementById('cb85edc54f124960ba93855b5f072836'), 'white', {renderer: 'canvas'});
#         var option_cb85edc54f124960ba93855b5f072836 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7b2c\u4e00\u5b63\u5ea6",
#             "data": [
#                 93,
#                 123,
#                 102,
#                 87,
#                 91,
#                 25,
#                 145
#             ],
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7b2c\u4e8c\u5b63\u5ea6",
#             "data": [
#                 133,
#                 42,
#                 120,
#                 121,
#                 25,
#                 40,
#                 129
#             ],
#             "barCategoryGap": "20%",
#             "barGap": "0%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7b2c\u4e00\u5b63\u5ea6",
#                 "\u7b2c\u4e8c\u5b63\u5ea6"
#             ],
#             "selected": {
#                 "\u7b2c\u4e00\u5b63\u5ea6": true,
#                 "\u7b2c\u4e8c\u5b63\u5ea6": true
#             },
#             "selectedMode": "single",
#             "show": true,
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ]
# };
#         chart_cb85edc54f124960ba93855b5f072836.setOption(option_cb85edc54f124960ba93855b5f072836);
#     });
# </script>

# %%
y_values = [(x,y) for x,y in zip(Faker.values(),Faker.values())]
print(y_values)
c = (
    Scatter(init_opts=opts.InitOpts(width="500px",height="300px"))
    .add_xaxis(Faker.clothes)
    .add_yaxis("销售",y_values)
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(type_="color",range_text=['大','小'])
    )
)
c.render_notebook()
# Out:
# [(67, 143), (35, 35), (102, 20), (79, 79), (143, 92), (21, 25), (70, 134)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="0841a24ba060453dad62df5b2dbfd897" style="width:500px; height:300px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_0841a24ba060453dad62df5b2dbfd897 = echarts.init(
#             document.getElementById('0841a24ba060453dad62df5b2dbfd897'), 'white', {renderer: 'canvas'});
#         var option_0841a24ba060453dad62df5b2dbfd897 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u9500\u552e",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     67,
#                     143
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     35,
#                     35
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     102,
#                     20
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     79,
#                     79
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     143,
#                     92
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     21,
#                     25
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     70,
#                     134
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9500\u552e"
#             ],
#             "selected": {
#                 "\u9500\u552e": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "text": [
#             "\u5927",
#             "\u5c0f"
#         ],
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_0841a24ba060453dad62df5b2dbfd897.setOption(option_0841a24ba060453dad62df5b2dbfd897);
#     });
# </script>

# %%
c = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A",Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Scatter-多维度数据"),
        tooltip_opts=opts.TooltipOpts(
            formatter=JsCode("function(params){return params.name+ params.value[1]}")
        )
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="c1d2de45f79b4660a567e1e64a5ba153" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_c1d2de45f79b4660a567e1e64a5ba153 = echarts.init(
#             document.getElementById('c1d2de45f79b4660a567e1e64a5ba153'), 'white', {renderer: 'canvas'});
#         var option_c1d2de45f79b4660a567e1e64a5ba153 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     132
#                 ],
#                 [
#                     "\u8292\u679c",
#                     139
#                 ],
#                 [
#                     "\u8461\u8404",
#                     36
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     92
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     106
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     81
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     68
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function(params){return params.name+ params.value[1]},
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u591a\u7ef4\u5ea6\u6570\u636e"
#         }
#     ]
# };
#         chart_c1d2de45f79b4660a567e1e64a5ba153.setOption(option_c1d2de45f79b4660a567e1e64a5ba153);
#     });
# </script>

# %%
c = (
    Bar()
    .add_xaxis(
        [
        "名字很长的X轴标签1",
        "名字很长的X轴标签2",
        "名字很长的X轴标签3",
        "名字很长的X轴标签4",
        "名字很长的X轴标签5",
        "名字很长的X轴标签6",
        ]
    )
    .add_yaxis("商家A", [10, 20, 30, 40, 50, 40])
    .add_yaxis("商家B", [20, 10, 40, 30, 40, 50])
    .set_global_opts(
    xaxis_opts=opts.AxisOpts(
        name="商家名称",
        axislabel_opts=opts.LabelOpts(rotate=-15),
        axisline_opts = opts.AxisLineOpts(symbol="arrow",linestyle_opts=opts.LineStyleOpts(width=2)),
        axistick_opts = opts.AxisTickOpts(is_inside=True,length=20),
        axispointer_opts = opts.AxisPointerOpts(is_show=True,type_="line")
        )
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="fa35cf5753f14371b2ee89da303dbdcd" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_fa35cf5753f14371b2ee89da303dbdcd = echarts.init(
#             document.getElementById('fa35cf5753f14371b2ee89da303dbdcd'), 'white', {renderer: 'canvas'});
#         var option_fa35cf5753f14371b2ee89da303dbdcd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 10,
#                 20,
#                 30,
#                 40,
#                 50,
#                 40
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 20,
#                 10,
#                 40,
#                 30,
#                 40,
#                 50
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "name": "\u5546\u5bb6\u540d\u79f0",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "symbol": "arrow",
#                 "lineStyle": {
#                     "width": 2,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": true,
#                 "length": 20
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "axisPointer": {
#                 "show": true,
#                 "type": "line"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e1",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e2",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e3",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e4",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e5",
#                 "\u540d\u5b57\u5f88\u957f\u7684X\u8f74\u6807\u7b7e6"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ]
# };
#         chart_fa35cf5753f14371b2ee89da303dbdcd.setOption(option_fa35cf5753f14371b2ee89da303dbdcd);
#     });
# </script>
