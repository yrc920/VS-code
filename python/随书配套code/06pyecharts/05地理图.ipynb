# %%
from pyecharts.charts import Map
from pyecharts import options as opts
from faker import Faker

# %%
c = (
    Map()
    .add("淘宝商家商品售卖情况",[(x,y) for x,y in zip(Faker.provinces,Faker.values())],"china")
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts()
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="ce83a9d3e0094c9aa2585a7cc3cdfbbc" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_ce83a9d3e0094c9aa2585a7cc3cdfbbc = echarts.init(
#             document.getElementById('ce83a9d3e0094c9aa2585a7cc3cdfbbc'), 'white', {renderer: 'canvas'});
#         var option_ce83a9d3e0094c9aa2585a7cc3cdfbbc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u6dd8\u5b9d\u5546\u5bb6\u5546\u54c1\u552e\u5356\u60c5\u51b5",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 149
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6dd8\u5b9d\u5546\u5bb6\u5546\u54c1\u552e\u5356\u60c5\u51b5"
#             ],
#             "selected": {
#                 "\u6dd8\u5b9d\u5546\u5bb6\u5546\u54c1\u552e\u5356\u60c5\u51b5": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {}
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_ce83a9d3e0094c9aa2585a7cc3cdfbbc.setOption(option_ce83a9d3e0094c9aa2585a7cc3cdfbbc);
#     });
# </script>

# %%
c = (
    Map()
    .add("广东省各城市人口密度",[(x,y) for x,y in zip(Faker.guangdong_city,Faker.values())],"广东")
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts()
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#     <div id="7f0286c4d56443ed925a529405c0ba61" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', '广东'], function(echarts) {
#         var chart_7f0286c4d56443ed925a529405c0ba61 = echarts.init(
#             document.getElementById('7f0286c4d56443ed925a529405c0ba61'), 'white', {renderer: 'canvas'});
#         var option_7f0286c4d56443ed925a529405c0ba61 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5e7f\u4e1c\u7701\u5404\u57ce\u5e02\u4eba\u53e3\u5bc6\u5ea6",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u5e7f\u4e1c",
#             "data": [
#                 {
#                     "name": "\u6c55\u5934\u5e02",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u6c55\u5c3e\u5e02",
#                     "value": 87
#                 },
#                 {
#                     "name": "\u63ed\u9633\u5e02",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u9633\u6c5f\u5e02",
#                     "value": 84
#                 },
#                 {
#                     "name": "\u8087\u5e86\u5e02",
#                     "value": 148
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u60e0\u5dde\u5e02",
#                     "value": 145
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u4e1c\u7701\u5404\u57ce\u5e02\u4eba\u53e3\u5bc6\u5ea6"
#             ],
#             "selected": {
#                 "\u5e7f\u4e1c\u7701\u5404\u57ce\u5e02\u4eba\u53e3\u5bc6\u5ea6": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {}
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_7f0286c4d56443ed925a529405c0ba61.setOption(option_7f0286c4d56443ed925a529405c0ba61);
#     });
# </script>

# %%
c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.country, Faker.values())], "world")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-世界地图"),
        visualmap_opts=opts.VisualMapOpts(max_=200),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#     <div id="ea45743ba99141769d9f66a33a63c991" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'world'], function(echarts) {
#         var chart_ea45743ba99141769d9f66a33a63c991 = echarts.init(
#             document.getElementById('ea45743ba99141769d9f66a33a63c991'), 'white', {renderer: 'canvas'});
#         var option_ea45743ba99141769d9f66a33a63c991 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 96
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 40
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 93
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 66
#                 },
#                 {
#                     "name": "United States",
#                     "value": 125
#                 },
#                 {
#                     "name": "Africa",
#                     "value": 39
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 51
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-\u4e16\u754c\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_ea45743ba99141769d9f66a33a63c991.setOption(option_ea45743ba99141769d9f66a33a63c991);
#     });
# </script>
