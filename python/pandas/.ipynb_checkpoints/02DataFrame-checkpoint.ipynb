# %%
import numpy as np
import pandas as pd

# %%
# 使用二维数组（列表）创建DataFrame
array = np.random.randint(0,10, size=(5, 3))
# index：行索引。
# columns：列索引。
df1 = pd.DataFrame(array, index=list(range(10,15)), columns=['星期一', '星期二', '星期三'])
print(type(df1))
print(df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     星期一  星期二  星期三
# 10    1    4    9
# 11    2    9    7
# 12    4    5    8
# 13    1    0    6
# 14    5    1    6

# %%
# 使用字典来创建DataFrame
persons = [{"name": "张三", "age": 18, "height": 180}, {"name": "李四", "age": 28, "height": 187}]
df2 = pd.DataFrame(persons)
df2

# %%
perons3 = {"name": ['张三', '李四'], "age": [18, 28], "height": [180, 187]}
df3 = pd.DataFrame(perons3)
df3

# %% [markdown]
# # 查看DataFrame信息

# %%
# head方法
df = pd.read_csv("data/stock_day.csv")
df.head()

# %%
# tail方法
df.tail()

# %%
# describe
df.describe()

# %%
# shape
df.shape

# %%
# index：行索引
# columns：列索引
# df.index
df.columns

# %%
df.T

# %%
df.info()

# %%
df.dtypes

# %% [markdown]
# # DataFrame基本操作

# %%
# 获取某一列的数据
# df.open
# df['open']

# %%
# 一次性获取多列的数据
df[['open', "close"]]

# %%
# 获取某一行的数据
# index(下标) location
df.iloc[1]

# %%
# 增加新的列
df3['weight'] = [70, 80]
df3

# %%
# 删除列
del df3['height']
df3
